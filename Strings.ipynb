# %%
# Find the length of a given string without using the len() function

s = input("Enter the string:")

counter = 0

for i in s:
    counter += 1

print("Length of string is ",counter)
# Out:
# Enter the string: sakshi mohit
# Length of string is  12

# %%
# Extract username from a given email. 
# Eg if the email is sakshimohit1234@gmail.com 
# then the username should be sakshimohit.

s = input("Ener the string : ")
pos = s.index("@")
print(s[0:pos])
# Out:
# Ener the string :  sakshimohit1234@gmial.com
# sakshimohit1234

# %%
# Count the frequency of a particular character in a provided string. 
# Eg 'hello how are you' is the string, the frequency of h in this string is 2.

s = input("enter the string:")
term = input("what would u like to search :")

counter = 0

for i in s:
    if i == term:
        counter += 1
print("Frequency:",counter)
# Out:
# enter the string: hello how are you
# what would u like to search : o
# Frequency: 3

# %%
# Write a program which can remove a particular character from a string.

s = input("Enter the string:")
term = input("what would u like to remove :")

result = ""

for i in s:
    if i != term:
        result = result + i
print(result)
# Out:
# Enter the string: sakshimohit
# what would u like to remove : i
# sakshmoht

# %%
# Write a program that can check whether a given string is palindrome or not.

s = input("Enter the string:")

s = s.lower()

rev = ""
for i in range(len(s)-1, -1 , -1):
    rev = rev + s[i]
if rev == s:
    print("Palindrome")
else:
    print("not palindrome")
# Out:
# Enter the string: abba
# Palindrome

# %%
# Write a program to count the number of words in a string without split().

s = input("Enter the string : ")

count = 0

for i in range(len(s)):
    if s[i] != " " and (i == 0 or s[i-1] == " "):
        count += 1

print("no of Words", count)
# Out:
# Enter the string :  sakshi mohit
# no of Words 2
