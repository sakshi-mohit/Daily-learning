# %% [markdown]
# Series with python functionalities

# %%
import numpy as  np
import pandas as  pd

# %%
subs = pd.read_csv("subs.csv")
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
print(len(subs))
# Out:
# 365

# %%
print(type(subs))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(sorted(subs))
# Out:
# ['Subscribers gained']

# %%
# custom index
marks = [65,78,75,80]
subjects = ["java","DS","python","sql"]

marks_series = (pd.Series(marks,index = subjects))
# Out:
# java      65
# DS        78
# python    75
# sql       80
# dtype: int64

# %%
for i in subs:
    print(i)
# Out:
# Subscribers gained

# %%
#relational operors
vk =(pd.read_csv("kohli_ipl.csv",index_col = "match_no"))
vk >= 50
# Out:
#            runs
# match_no
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# ...         ...
# 211       False
# 212       False
# 213        True
# 214       False
# 215       False
#
# [215 rows x 1 columns]

# %% [markdown]
# Boolean indexing on series

# %%
# find no of 50 s and 100 s  scored by kholi
vk[vk >= 50].size
# Out:
# 215

# %%
# find no. of ducks 
vk[vk == 0]
# Out:
#           runs
# match_no
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# ...        ...
# 211        0.0
# 212        NaN
# 213        NaN
# 214        NaN
# 215        NaN
#
# [215 rows x 1 columns]

# %%
subs[subs > 200]
# Out:
#      Subscribers gained
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...
# 360               231.0
# 361               226.0
# 362                 NaN
# 363                 NaN
# 364                 NaN
#
# [365 rows x 1 columns]

# %% [markdown]
# Plotting  graphs on series

# %%
subs.plot()
# Out:
# <Axes: >

# %%
#astype
import sys
sys.getsizeof(vk)
# Out:
# 3472

# %%
sys.getsizeof(vk.astype("int16"))
# Out:
# 2182

# %%
vk = pd.Series([10,20,30,50,52])

# %%
vk.between(30,52).sum
# Out:
# <bound method Series.sum of 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# dtype: bool>

# %%
subs.clip(100,200)
# Out:
#      Subscribers gained
# 0                   100
# 1                   100
# 2                   100
# 3                   100
# 4                   100
# ..                  ...
# 360                 200
# 361                 200
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
#drop duplicates
temp = pd.Series([1,1,2,2,3,3,4,4])
temp
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    3
# 5    3
# 6    4
# 7    4
# dtype: int64

# %%
temp.drop_duplicates()
# Out:
# 0    1
# 2    2
# 4    3
# 6    4
# dtype: int64

# %%
temp.duplicated().sum()
# Out:
# np.int64(4)

# %%
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp.count()
# Out:
# np.int64(7)

# %%
temp.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7    False
# 8     True
# 9    False
# dtype: bool

# %%
temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
temp.fillna(0)
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     0.0
# 4     5.0
# 5     6.0
# 6     0.0
# 7     8.0
# 8     0.0
# 9    10.0
# dtype: float64

# %%
#isin

(vk == 49) | (vk == 99)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
